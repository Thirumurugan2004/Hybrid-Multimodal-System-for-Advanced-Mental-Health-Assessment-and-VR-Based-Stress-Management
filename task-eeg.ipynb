# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/task-eeg-dataset/MDD/MDD S2 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S15 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S12 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S6 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S7 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S19 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S24 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S20 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S4 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S26 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S27 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S18 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S30 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S17 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S5 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S13 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S16 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S3 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S28 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S21 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S14 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S31 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S10 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S8 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S23 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S25 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S29 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S33 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S32 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S34 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S11 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S1 TASK.png
# /kaggle/input/task-eeg-dataset/MDD/MDD S22 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S29 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S17 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S5 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S28 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S26 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S12 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S9 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S30 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S19 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S8 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S15 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S3 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S6 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S1 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S22 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S24 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S13 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S27 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S2 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S18 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S11 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S4 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S16 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S14 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S10 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S23 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S25 TASK.png
# /kaggle/input/task-eeg-dataset/Healthy/H S7 TASK.png

# %%
import torch
import torch.nn as nn
from torchvision import models, datasets, transforms
from torch.utils.data import DataLoader, random_split

# %%
# Path to the main folder
main_folder = '/kaggle/input/task-eeg-dataset'

# Define transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # ResNet input size
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Normalization for pretrained ResNet
])

# Load dataset with ImageFolder
dataset = datasets.ImageFolder(root=main_folder, transform=transform)

# %%
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 2)  # Adjust the last layer for 2 classes
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
criterion = nn.CrossEntropyLoss()  # Loss for classification
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)  # Adam optimizer

# %%
def calculate_accuracy(loader, model):
    model.eval()  # Set to evaluation mode
    correct = 0
    total = 0
    with torch.no_grad():  # No gradient computation for evaluation
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
    return correct / total

# %%
pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.4.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (0.19.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
num_epochs = 5

for epoch in range(num_epochs):
    model.train()  # Set to training mode
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()  # Clear gradients
        outputs = model(images)  # Forward pass
        loss = criterion(outputs, labels)  # Compute loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Update weights
        
        running_loss += loss.item()
    
    # Calculate training and testing accuracy
    train_accuracy = calculate_accuracy(train_loader, model)
    test_accuracy = calculate_accuracy(test_loader, model)
    
    print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {running_loss / len(train_loader):.4f}, "
          f"Train Accuracy: {train_accuracy * 100:.2f}%, Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Epoch [1/5], Loss: 0.6760, Train Accuracy: 87.50%, Test Accuracy: 69.23%
# Epoch [2/5], Loss: 0.4917, Train Accuracy: 91.67%, Test Accuracy: 76.92%
# Epoch [3/5], Loss: 0.1067, Train Accuracy: 93.75%, Test Accuracy: 84.62%
# Epoch [4/5], Loss: 0.1496, Train Accuracy: 89.58%, Test Accuracy: 76.92%
# Epoch [5/5], Loss: 0.0326, Train Accuracy: 91.67%, Test Accuracy: 84.62%

# %%
# Define the path to save the model
model_save_path = '/kaggle/working/task_eeg_resnet.pth'
# Save the trained model's state dictionary
torch.save(model.state_dict(), model_save_path)

print(f"Model saved to {model_save_path}")
# Out:
# Model saved to /kaggle/working/task_eeg_resnet.pth

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

def get_predictions_and_labels(loader, model):
    model.eval()  # Set to evaluation mode
    all_preds = []
    all_labels = []
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    return all_preds, all_labels

# %%
# Get predictions and labels for the training set
train_preds, train_labels = get_predictions_and_labels(train_loader, model)

# Get predictions and labels for the test set
test_preds, test_labels = get_predictions_and_labels(test_loader, model)

# Generate confusion matrix for training set
train_cm = confusion_matrix(train_labels, train_preds)
train_disp = ConfusionMatrixDisplay(confusion_matrix=train_cm, display_labels=['Healthy', 'MDD'])
train_disp.plot(cmap='Blues')
plt.title("Training Set Confusion Matrix")
plt.show()

# Generate confusion matrix for test set
test_cm = confusion_matrix(test_labels, test_preds)
test_disp = ConfusionMatrixDisplay(confusion_matrix=test_cm, display_labels=['Healthy', 'MDD'])
test_disp.plot(cmap='Blues')
plt.title("Test Set Confusion Matrix")
plt.show()
